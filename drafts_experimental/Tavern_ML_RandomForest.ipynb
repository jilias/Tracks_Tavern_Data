# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
file_path = Path('../Resources/weekly_sales_complete.csv')
df = pd.read_csv(file_path)
df.columns =  df.columns.str.replace(' ','_')

df.head()
# Out:
#                    Item  Item_Code  Quantity  Unit_Price  Total_Sales_Amount  \
# 0      PINT Spotted Cow       3140      64.0    3.937500              252.00
# 1        DBL RAIL Vodka       3455      37.0    4.945946              183.00
# 2  BTL Miller High Life       3122      31.0    3.250000              100.75
# 3            PINT Stein       3141      29.0    3.517241              102.00
# 4      SHOT Seagrams VO       3325      26.0    2.423077               63.00
#
#          date
# 0  2021-01-08
# 1  2021-01-08
# 2  2021-01-08
# 3  2021-01-08
# 4  2021-01-08

# %%
columns = ["Item","Item_Code", "Quantity", "Unit_Price", "Total_Sales_Amount", "date"]

target = ["Total_Sales_Amount"]

# %%
df.dtypes
# Out:
# Item                   object
# Item_Code               int64
# Quantity              float64
# Unit_Price            float64
# Total_Sales_Amount    float64
# date                   object
# dtype: object

# %%
df.shape
# Out:
# (15585, 6)

# %%
data = df.sample(frac=0.90, random_state=600).reset_index(drop=True)
data_unseen = df.drop(data.index).reset_index(drop=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (21461, 6)
# Unseen Data For Predictions: (2385, 6)

# %%
# Create our features
X = pd.get_dummies(data=df, columns=['Total_Sales_Amount', 'date'])
# Create our target
y = df["Total_Sales_Amount"]

# %%
X.describe()
# Out:
#           Item_Code      Quantity    Unit_Price  Total_Sales_Amount_0.0  \
# count  23846.000000  23846.000000  23846.000000            23846.000000
# mean    3221.302944     11.079636      5.147705                0.052587
# std      278.452809     17.737029      4.944210                0.223213
# min     2696.000000      1.000000      0.000000                0.000000
# 25%     3113.000000      2.000000      3.000000                0.000000
# 50%     3234.000000      5.000000      4.304952                0.000000
# 75%     3452.000000     13.000000      7.000000                0.000000
# max     3717.000000    293.000000    206.000000                1.000000
#
#        Total_Sales_Amount_0.13  Total_Sales_Amount_0.25  \
# count             23846.000000             23846.000000
# mean                  0.000042                 0.014468
# std                   0.006476                 0.119412
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   1.000000                 1.000000
#
#        Total_Sales_Amount_0.26  Total_Sales_Amount_0.5  \
# count             23846.000000            23846.000000
# mean                  0.000042                0.006542
# std                   0.006476                0.080619
# min                   0.000000                0.000000
# 25%                   0.000000                0.000000
# 50%                   0.000000                0.000000
# 75%                   0.000000                0.000000
# max                   1.000000                1.000000
#
#        Total_Sales_Amount_0.53  Total_Sales_Amount_0.63  ...  date_2021-07-23  \
# count             23846.000000             23846.000000  ...     23846.000000
# mean                  0.000042                 0.000084  ...         0.008094
# std                   0.006476                 0.009158  ...         0.089602
# min                   0.000000                 0.000000  ...         0.000000
# 25%                   0.000000                 0.000000  ...         0.000000
# 50%                   0.000000                 0.000000  ...         0.000000
# 75%                   0.000000                 0.000000  ...         0.000000
# max                   1.000000                 1.000000  ...         1.000000
#
#        date_2021-07-30  date_2021-08-06  date_2021-08-13  date_2021-08-20  \
# count     23846.000000     23846.000000     23846.000000     23846.000000
# mean          0.007632         0.007213         0.007171         0.007716
# std           0.087031         0.084624         0.084379         0.087504
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         0.000000         0.000000
# max           1.000000         1.000000         1.000000         1.000000
#
#        date_2021-08-27  date_2021-09-03  date_2021-09-10  date_2021-09-17  \
# count     23846.000000     23846.000000     23846.000000     23846.000000
# mean          0.007339         0.007297         0.007800         0.007548
# std           0.085353         0.085111         0.087975         0.086555
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         0.000000         0.000000
# max           1.000000         1.000000         1.000000         1.000000
#
#        date_2021-09-24
# count     23846.000000
# mean          0.007674
# std           0.087268
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
#
# [8 rows x 1634 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1)
Counter(y_train)
# Out:
# Counter({10.0: 296,
#          28.0: 203,
#          19.5: 59,
#          36.0: 197,
#          16.0: 478,
#          7.0: 368,
#          120.5: 3,
#          39.0: 57,
#          7.5: 111,
#          74.0: 5,
#          12.0: 496,
#          14.0: 241,
#          0.0: 958,
#          30.0: 234,
#          63.0: 73,
#          97.0: 6,
#          68.0: 38,
#          201.0: 2,
#          49.75: 8,
#          9.0: 272,
#          28.5: 29,
#          60.0: 155,
#          45.0: 129,
#          272.0: 5,
#          5974.0: 1,
#          6.0: 444,
#          0.5: 120,
#          81.0: 34,
#          5.0: 385,
#          49.5: 30,
#          8.0: 715,
#          244.6: 1,
#          32.0: 206,
#          88.0: 65,
#          15.0: 293,
#          3.0: 421,
#          105.5: 7,
#          4.0: 567,
#          27.0: 115,
#          1.5: 341,
#          54.0: 61,
#          256.0: 8,
#          13.0: 88,
#          53.0: 12,
#          243.75: 1,
#          160.0: 27,
#          21.0: 185,
#          360.0: 7,
#          90.5: 17,
#          41.0: 16,
#          171.5: 1,
#          288.0: 3,
#          150.0: 34,
#          132.0: 38,
#          20.0: 284,
#          22.0: 49,
#          144.25: 1,
#          2.0: 60,
#          13.5: 86,
#          0.75: 110,
#          59.25: 1,
#          3.75: 9,
#          40.0: 184,
#          0.25: 268,
#          15.5: 14,
#          46.0: 15,
#          12.25: 2,
#          4.5: 224,
#          117.5: 5,
#          35.0: 103,
#          130.0: 16,
#          87.0: 22,
#          52.0: 64,
#          42.0: 101,
#          372.0: 5,
#          3.5: 130,
#          104.0: 33,
#          267.0: 2,
#          215.0: 7,
#          170.87: 1,
#          122.5: 5,
#          169.5: 6,
#          64.0: 87,
#          244.0: 4,
#          420.0: 7,
#          71.0: 7,
#          117.0: 34,
#          17.5: 39,
#          32.5: 36,
#          18.0: 242,
#          99.5: 5,
#          51.5: 13,
#          153.25: 1,
#          24.0: 399,
#          50.0: 36,
#          144.0: 26,
#          56.0: 123,
#          48.5: 17,
#          79.0: 10,
#          9.95: 16,
#          154.5: 6,
#          180.0: 31,
#          93.0: 24,
#          149.5: 9,
#          6.5: 82,
#          58.63: 1,
#          108.0: 35,
#          125.0: 14,
#          165.0: 35,
#          33.0: 71,
#          168.0: 18,
#          167.75: 3,
#          55.5: 16,
#          162.0: 8,
#          204.0: 10,
#          176.0: 19,
#          102.5: 2,
#          73.0: 14,
#          20.5: 22,
#          96.0: 53,
#          156.0: 27,
#          11.0: 72,
#          81.5: 9,
#          198.0: 13,
#          124.5: 11,
#          68.5: 4,
#          176.5: 2,
#          72.0: 97,
#          121.5: 12,
#          240.0: 19,
#          170.0: 13,
#          310.0: 2,
#          154.0: 9,
#          179.5: 2,
#          111.0: 14,
#          131.0: 5,
#          19.9: 17,
#          22.5: 78,
#          86.0: 6,
#          256.5: 3,
#          1.55: 11,
#          30.25: 5,
#          255.0: 14,
#          120.0: 72,
#          230.0: 2,
#          29.25: 8,
#          90.0: 72,
#          23.0: 21,
#          33.25: 1,
#          676.0: 1,
#          37.38: 1,
#          80.0: 67,
#          137.0: 5,
#          181.5: 2,
#          770.0: 1,
#          26.0: 60,
#          88.5: 8,
#          75.0: 63,
#          114.0: 20,
#          180.5: 5,
#          43.96: 1,
#          116.5: 5,
#          44.0: 70,
#          66.0: 59,
#          70.0: 34,
#          16.5: 29,
#          96.5: 6,
#          10.5: 60,
#          25.0: 75,
#          1.75: 35,
#          145.0: 8,
#          73.5: 13,
#          160.5: 7,
#          181.6: 2,
#          19.0: 20,
#          30.75: 1,
#          44.25: 4,
#          19.75: 2,
#          374.0: 3,
#          236.43: 1,
#          299.0: 3,
#          121.75: 1,
#          84.0: 68,
#          295.0: 2,
#          77.0: 19,
#          124.0: 16,
#          52.5: 28,
#          9.75: 35,
#          22.75: 26,
#          31.5: 41,
#          45.5: 35,
#          281.0: 2,
#          48.0: 153,
#          34.0: 17,
#          51.0: 24,
#          64.25: 3,
#          308.0: 5,
#          321.5: 1,
#          70.5: 11,
#          112.0: 32,
#          209.0: 8,
#          108.5: 12,
#          210.0: 21,
#          79.5: 5,
#          94.5: 12,
#          627.0: 1,
#          190.0: 5,
#          104.5: 7,
#          136.0: 32,
#          15.75: 3,
#          9.5: 12,
#          208.0: 8,
#          12.5: 31,
#          39.5: 9,
#          65.0: 36,
#          57.0: 42,
#          66.5: 12,
#          370.25: 1,
#          29.85: 9,
#          140.0: 28,
#          48.75: 7,
#          197.5: 2,
#          34.5: 23,
#          164.0: 14,
#          96.94: 1,
#          356.0: 2,
#          794.25: 1,
#          147.0: 15,
#          58.5: 27,
#          38.25: 2,
#          5.25: 8,
#          184.0: 9,
#          44.75: 2,
#          61.5: 14,
#          1.0: 58,
#          49.0: 38,
#          105.0: 52,
#          247.5: 7,
#          346.0: 1,
#          196.0: 9,
#          64.5: 13,
#          182.5: 4,
#          68.25: 5,
#          139.5: 5,
#          23.75: 3,
#          332.0: 5,
#          40.5: 38,
#          116.0: 20,
#          951.75: 1,
#          126.0: 11,
#          207.5: 3,
#          153.0: 12,
#          38.0: 19,
#          101.0: 6,
#          42.25: 5,
#          62.0: 9,
#          262.5: 2,
#          129.85: 1,
#          319.0: 6,
#          136.5: 4,
#          222.0: 3,
#          38.75: 1,
#          148.0: 13,
#          440.0: 3,
#          71.5: 10,
#          55.0: 35,
#          330.0: 9,
#          200.0: 11,
#          325.9: 1,
#          91.5: 14,
#          24.5: 24,
#          180.25: 1,
#          118.5: 6,
#          103.0: 5,
#          315.0: 5,
#          1032.25: 1,
#          275.0: 3,
#          188.0: 9,
#          65.5: 6,
#          135.0: 41,
#          3.25: 31,
#          37.5: 13,
#          320.0: 1,
#          155.75: 2,
#          129.92: 2,
#          152.0: 9,
#          155.0: 6,
#          122.0: 8,
#          78.5: 7,
#          94.25: 2,
#          95.5: 4,
#          3.1: 4,
#          31.0: 18,
#          53.5: 6,
#          204.75: 3,
#          207.0: 4,
#          174.0: 5,
#          110.5: 10,
#          85.0: 17,
#          416.0: 2,
#          43.0: 11,
#          35.75: 10,
#          388.0: 2,
#          95.0: 8,
#          60.5: 10,
#          203.0: 1,
#          113.0: 11,
#          165.75: 3,
#          246.0: 3,
#          112.5: 18,
#          99.0: 26,
#          123.0: 9,
#          192.0: 20,
#          291.8: 1,
#          253.0: 5,
#          82.0: 16,
#          264.0: 8,
#          464.75: 1,
#          211.0: 3,
#          120.95: 1,
#          42.5: 18,
#          41.5: 4,
#          127.0: 3,
#          37.0: 17,
#          285.0: 5,
#          5.5: 21,
#          600.0: 1,
#          110.75: 1,
#          158.5: 2,
#          55.25: 8,
#          1.38: 1,
#          92.0: 16,
#          27.5: 12,
#          273.0: 4,
#          35.5: 13,
#          341.25: 1,
#          312.0: 3,
#          195.0: 21,
#          387.5: 1,
#          69.0: 23,
#          2.25: 40,
#          132.85: 2,
#          287.25: 1,
#          539.0: 4,
#          143.5: 2,
#          82.5: 6,
#          197.0: 4,
#          78.0: 22,
#          76.5: 18,
#          32.85: 3,
#          74.75: 3,
#          19.98: 7,
#          76.65: 1,
#          76.0: 40,
#          42.8: 1,
#          165.5: 4,
#          216.0: 8,
#          79.94: 2,
#          261.0: 7,
#          1.25: 27,
#          129.0: 10,
#          303.0: 1,
#          67.5: 21,
#          142.8: 1,
#          300.0: 6,
#          133.0: 6,
#          177.0: 8,
#          117.25: 2,
#          109.5: 11,
#          95.6: 2,
#          159.5: 3,
#          54.5: 15,
#          100.5: 9,
#          98.0: 15,
#          957.0: 2,
#          57.5: 6,
#          8.25: 7,
#          119.0: 5,
#          114.75: 1,
#          229.0: 3,
#          146.0: 6,
#          109.0: 11,
#          249.0: 4,
#          89.25: 1,
#          84.5: 10,
#          608.0: 1,
#          141.8: 2,
#          412.0: 3,
#          205.0: 3,
#          630.0: 2,
#          159.0: 8,
#          719.0: 1,
#          674.0: 1,
#          179.89: 1,
#          2.5: 30,
#          220.1: 1,
#          219.6: 1,
#          110.0: 25,
#          6.75: 10,
#          228.75: 1,
#          58.0: 13,
#          102.0: 25,
#          79.95: 3,
#          444.0: 2,
#          436.0: 1,
#          43.5: 13,
#          46.75: 1,
#          265.5: 3,
#          194.05: 1,
#          94.0: 4,
#          63.5: 11,
#          28.75: 1,
#          9.99: 13,
#          361.5: 1,
#          26.75: 2,
#          118.0: 4,
#          216.35: 1,
#          17.0: 9,
#          83.5: 8,
#          144.75: 2,
#          47.5: 6,
#          158.0: 2,
#          138.0: 10,
#          252.75: 1,
#          262.8: 1,
#          164.5: 2,
#          212.0: 10,
#          433.7: 1,
#          2.75: 5,
#          629.9992: 1,
#          511.0: 1,
#          111.93: 1,
#          690.0: 1,
#          18.5: 12,
#          123.25: 1,
#          8.5: 15,
#          49.95: 3,
#          29.0: 15,
#          156.5: 4,
#          228.0: 11,
#          61.75: 9,
#          262.7: 1,
#          187.0: 7,
#          202.5: 7,
#          154.3: 1,
#          59.5: 6,
#          25.5: 20,
#          234.0: 6,
#          115.5: 11,
#          141.0: 15,
#          182.6: 1,
#          219.5: 1,
#          89.0: 9,
#          56.5: 8,
#          168.5: 4,
#          286.5: 2,
#          91.0: 15,
#          130.5: 10,
#          151.0: 4,
#          297.0: 5,
#          221.0: 3,
#          130.4: 2,
#          224.25: 1,
#          145.39: 1,
#          115.0: 9,
#          183.5: 2,
#          14.5: 12,
#          81.25: 4,
#          24.25: 3,
#          836.0: 1,
#          277.5: 1,
#          206.5: 1,
#          137.5: 3,
#          86.5: 3,
#          90.75: 1,
#          106.5: 10,
#          175.5: 3,
#          140.05: 1,
#          117.91: 2,
#          50.5: 10,
#          429.0: 4,
#          348.0: 3,
#          252.0: 9,
#          63.25: 1,
#          290.75: 1,
#          107.5: 4,
#          155.25: 2,
#          46.5: 12,
#          121.0: 8,
#          80.5: 9,
#          563.0: 1,
#          184.5: 3,
#          231.0: 10,
#          312.5: 2,
#          245.0: 2,
#          189.0: 9,
#          226.5: 3,
#          174.25: 2,
#          260.0: 10,
#          682.0: 2,
#          435.0: 4,
#          241.0: 3,
#          618.0: 2,
#          158.88: 1,
#          284.0: 5,
#          29.5: 7,
#          100.0: 28,
#          268.0: 2,
#          196.5: 2,
#          187.5: 5,
#          178.3: 1,
#          34.13: 1,
#          78.44: 1,
#          224.0: 5,
#          131.5: 5,
#          133.5: 5,
#          30.5: 11,
#          77.5: 7,
#          431.5: 1,
#          23.25: 4,
#          74.5: 8,
#          143.0: 15,
#          345.0: 6,
#          230.45: 1,
#          390.0: 3,
#          164.75: 2,
#          340.0: 3,
#          171.0: 4,
#          107.0: 5,
#          128.5: 5,
#          159.35: 1,
#          29.97: 1,
#          85.5: 10,
#          527.75: 1,
#          217.25: 1,
#          255.25: 1,
#          248.5: 1,
#          304.5: 2,
#          132.9: 1,
#          148.5: 6,
#          33.03: 1,
#          139.0: 3,
#          284.75: 1,
#          97.5: 8,
#          59.7: 1,
#          583.0: 2,
#          37.75: 2,
#          48.47: 5,
#          60.25: 2,
#          304.0: 4,
#          194.0: 7,
#          59.0: 10,
#          270.0: 8,
#          44.5: 3,
#          550.0: 3,
#          222.5: 4,
#          191.88: 1,
#          510.25: 1,
#          181.86: 3,
#          225.0: 13,
#          38.5: 11,
#          232.0: 4,
#          13.75: 1,
#          195.38: 1,
#          473.0: 3,
#          172.5: 3,
#          255.75: 1,
#          232.85: 1,
#          97.27: 1,
#          406.25: 1,
#          255.5: 3,
#          486.0: 1,
#          145.75: 2,
#          142.85: 3,
#          166.5: 7,
#          230.85: 1,
#          432.0: 2,
#          127.5: 7,
#          199.0: 2,
#          501.5: 1,
#          21.5: 12,
#          179.0: 4,
#          367.25: 2,
#          220.0: 8,
#          194.5: 4,
#          316.0: 1,
#          47.0: 9,
#          126.75: 2,
#          565.75: 1,
#          16.25: 16,
#          42.38: 1,
#          166.0: 2,
#          324.0: 8,
#          10.49: 1,
#          258.0: 2,
#          439.5: 1,
#          113.43: 1,
#          125.5: 3,
#          265.7: 1,
#          484.0: 3,
#          587.0: 1,
#          709.0: 1,
#          1.01: 1,
#          315.25: 1,
#          132.35: 1,
#          128.75: 1,
#          242.0: 4,
#          128.0: 19,
#          638.0: 2,
#          67.0: 12,
#          237.25: 1,
#          26.5: 8,
#          41.46: 1,
#          185.0: 8,
#          121.25: 2,
#          326.15: 1,
#          213.25: 1,
#          520.0: 1,
#          41.25: 4,
#          193.5: 3,
#          213.0: 7,
#          153.75: 2,
#          528.0: 3,
#          397.0: 1,
#          524.0: 1,
#          280.0: 3,
#          424.75: 1,
#          373.0: 2,
#          465.0: 1,
#          495.0: 5,
#          180.75: 2,
#          309.5: 1,
#          210.34: 1,
#          74.25: 2,
#          95.94: 3,
#          375.0: 4,
#          232.5: 1,
#          244.5: 2,
#          11.5: 4,
#          25.25: 2,
#          540.0: 6,
#          383.5: 1,
#          331.0: 1,
#          652.75: 1,
#          50.25: 2,
#          82.1: 1,
#          103.92: 1,
#          153.5: 3,
#          191.0: 2,
#          83.0: 5,
#          194.85: 1,
#          72.5: 8,
#          55.26: 1,
#          1089.0: 2,
#          418.0: 2,
#          242.5: 1,
#          61.25: 2,
#          103.5: 6,
#          270.5: 1,
#          118.41: 2,
#          8.75: 2,
#          245.75: 1,
#          134.0: 6,
#          338.5: 2,
#          10.99: 1,
#          364.0: 4,
#          145.89: 1,
#          616.0: 1,
#          11.25: 6,
#          340.75: 1,
#          248.0: 4,
#          141.75: 1,
#          146.5: 5,
#          221.5: 1,
#          307.5: 2,
#          182.0: 6,
#          628.0: 1,
#          327.0: 1,
#          243.0: 3,
#          46.25: 1,
#          192.38: 1,
#          185.25: 2,
#          147.5: 1,
#          414.0: 1,
#          317.5: 1,
#          462.0: 6,
#          65.25: 1,
#          101.5: 8,
#          355.0: 1,
#          20.75: 3,
#          660.0: 1,
#          867.0: 1,
#          142.0: 6,
#          143.89: 1,
#          733.75: 1,
#          139.8: 2,
#          132.5: 5,
#          174.5: 5,
#          80.25: 2,
#          214.0: 2,
#          41.8: 2,
#          236.0: 4,
#          173.0: 2,
#          92.5: 4,
#          363.0: 2,
#          149.0: 4,
#          328.0: 4,
#          98.5: 4,
#          218.25: 1,
#          280.85: 1,
#          423.0: 1,
#          337.6: 1,
#          220.5: 4,
#          23.5: 5,
#          176.87: 1,
#          142.5: 2,
#          437.5: 1,
#          200.5: 3,
#          286.0: 5,
#          279.5: 1,
#          172.0: 6,
#          123.63: 1,
#          654.0: 1,
#          54.75: 1,
#          251.25: 1,
#          161.5: 4,
#          476.5: 1,
#          298.5: 1,
#          221.9: 1,
#          162.2: 3,
#          123.75: 2,
#          287.0: 1,
#          296.0: 4,
#          16.49: 2,
#          43.8: 2,
#          271.5: 1,
#          178.15: 1,
#          75.5: 11,
#          282.25: 1,
#          126.5: 3,
#          18.25: 1,
#          20.4: 4,
#          157.25: 1,
#          128.25: 1,
#          1.63: 1,
#          71.75: 1,
#          141.25: 2,
#          31.25: 1,
#          75.75: 2,
#          477.5: 1,
#          150.5: 2,
#          169.0: 5,
#          87.75: 3,
#          628.5: 1,
#          31.97: 1,
#          162.5: 5,
#          525.0: 3,
#          438.0: 1,
#          173.5: 2,
#          545.0: 1,
#          26.98: 1,
#          61.0: 9,
#          235.0: 2,
#          111.45: 1,
#          62.5: 3,
#          989.5: 1,
#          212.5: 2,
#          322.0: 1,
#          211.25: 2,
#          93.5: 1,
#          74.15: 1,
#          135.5: 3,
#          273.65: 1,
#          135.88: 1,
#          566.5: 1,
#          403.0: 2,
#          310.5: 1,
#          333.0: 1,
#          40.46: 2,
#          120.25: 6,
#          328.15: 1,
#          869.0: 2,
#          266.45: 1,
#          163.2: 2,
#          88.25: 2,
#          65.45: 1,
#          127.75: 1,
#          179.6: 1,
#          111.5: 3,
#          89.5: 4,
#          155.5: 1,
#          436.5: 1,
#          691.5: 1,
#          132.75: 1,
#          157.0: 4,
#          240.5: 2,
#          407.0: 3,
#          348.5: 1,
#          112.43: 1,
#          106.0: 6,
#          370.0: 1,
#          309.0: 1,
#          198.5: 1,
#          93.75: 1,
#          157.5: 6,
#          51.25: 1,
#          245.3: 1,
#          453.0: 1,
#          39.96: 2,
#          131.35: 2,
#          185.75: 1,
#          516.0: 1,
#          238.5: 1,
#          163.0: 2,
#          119.75: 1,
#          31.85: 2,
#          352.0: 3,
#          641.0: 1,
#          257.0: 2,
#          32.25: 2,
#          145.85: 1,
#          191.5: 4,
#          468.0: 1,
#          36.5: 6,
#          133.25: 2,
#          52.75: 1,
#          183.0: 5,
#          4.75: 1,
#          443.5: 1,
#          190.05: 1,
#          247.0: 2,
#          305.5: 1,
#          12.95: 3,
#          291.3: 1,
#          112.93: 1,
#          108.75: 1,
#          32.48: 2,
#          129.42: 2,
#          186.0: 6,
#          291.0: 1,
#          292.0: 3,
#          224.33: 1,
#          178.75: 2,
#          160.35: 1,
#          250.25: 1,
#          144.5: 4,
#          346.5: 1,
#          136.75: 1,
#          33.5: 6,
#          167.0: 1,
#          328.5: 1,
#          52.25: 1,
#          87.5: 2,
#          193.0: 2,
#          280.5: 2,
#          746.0: 1,
#          237.0: 3,
#          47.25: 2,
#          393.55: 1,
#          1021.0: 1,
#          101.25: 1,
#          91.75: 1,
#          178.45: 1,
#          29.75: 1,
#          480.0: 3,
#          370.5: 3,
#          40.96: 1,
#          209.95: 1,
#          227.5: 1,
#          320.5: 1,
#          192.05: 2,
#          235.95: 1,
#          149.25: 2,
#          107.25: 6,
#          31.47: 1,
#          108.25: 2,
#          7.75: 2,
#          225.5: 1,
#          109.75: 1,
#          262.0: 2,
#          601.25: 1,
#          585.0: 2,
#          223.5: 1,
#          96.25: 2,
#          914.5: 1,
#          130.9: 1,
#          91.05: 1,
#          510.0: 1,
#          96.44: 2,
#          205.5: 2,
#          203.5: 3,
#          331.5: 1,
#          609.0: 1,
#          0.63: 2,
#          341.0: 4,
#          144.8: 1,
#          126.38: 1,
#          231.95: 1,
#          251.95: 1,
#          171.75: 1,
#          156.88: 1,
#          219.0: 2,
#          178.5: 3,
#          170.15: 3,
#          209.5: 1,
#          82.25: 1,
#          704.0: 2,
#          187.15: 1,
#          70.65: 1,
#          139.75: 1,
#          405.0: 3,
#          280.25: 1,
#          100.25: 2,
#          167.5: 1,
#          213.95: 1,
#          198.1: 1,
#          349.0: 1,
#          170.37: 1,
#          250.0: 3,
#          334.75: 1,
#          227.0: 2,
#          555.0: 3,
#          247.8: 1,
#          150.75: 1,
#          133.4: 1,
#          103.75: 1,
#          150.25: 1,
#          572.0: 1,
#          220.25: 1,
#          130.42: 1,
#          313.5: 3,
#          79.26: 1,
#          651.5: 1,
#          190.25: 1,
#          121.4: 1,
#          67.45: 1,
#          332.5: 1,
#          145.5: 2,
#          15.25: 4,
#          241.5: 1,
#          304.25: 1,
#          192.75: 1,
#          243.5: 1,
#          332.65: 1,
#          123.85: 1,
#          226.75: 1,
#          56.25: 2,
#          20.48: 1,
#          511.5: 1,
#          330.75: 1,
#          212.95: 1,
#          144.69: 1,
#          52.46: 1,
#          41.38: 1,
#          77.25: 1,
#          781.75: 1,
#          506.0: 2,
#          35.85: 1,
#          216.5: 2,
#          57.25: 2,
#          110.25: 1,
#          132.95: 1,
#          177.2: 1,
#          64.46: 1,
#          233.0: 1,
#          293.5: 3,
#          576.0: 2,
#          339.0: 1,
#          134.5: 4,
#          354.0: 1,
#          338.0: 1,
#          615.0: 1,
#          343.95: 1,
#          93.25: 3,
#          20.25: 2,
#          113.75: 1,
#          336.0: 2,
#          381.0: 2,
#          344.0: 2,
#          105.75: 1,
#          451.0: 1,
#          272.5: 1,
#          276.35: 1,
#          737.0: 1,
#          658.75: 1,
#          163.5: 3,
#          253.5: 2,
#          300.5: 1,
#          466.0: 1,
#          284.5: 1,
#          54.25: 1,
#          130.25: 2,
#          208.5: 2,
#          397.5: 1,
#          211.5: 3,
#          145.91: 1,
#          385.0: 4,
#          262.58: 1,
#          62.25: 2,
#          276.0: 2,
#          ...})
