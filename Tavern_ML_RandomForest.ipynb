# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
file_path = Path('C:/Users/Rica6/Tracks_Tavern_Data/Resources/weekly_sales.csv')
df = pd.read_csv(file_path)
df.columns =  df.columns.str.replace(' ','_')

# Drop the null rows
#df = df.dropna()

# Convert the target column values to 0 and 1 based on their values
#x = {'Current': '0'}   
#df = df.replace(x)

df.head()
# Out:
#                     Item  Item_Code  Quantity  Unit_Price  Total_Sales_Amount  \
# 0             RAIL Vodka       3339      46.0    4.826087               222.0
# 1          PINT LKFT IPA       3136      44.0    3.579545               157.5
# 2     SHOT Tullamore Dew       3327      38.0    4.000000               152.0
# 3       PINT Spotted Cow       3140      36.0    3.750000               135.0
# 4  PINT Miller High Life       3137      30.0    3.000000                90.0
#
#          date
# 0  2019-02-15
# 1  2019-02-15
# 2  2019-02-15
# 3  2019-02-15
# 4  2019-02-15

# %%
columns = ["Item","Item_Code", "Quantity", "Unit_Price", "Total_Sales_Amount", "date"]

target = ["Total_Sales_Amount"]

# %%
df.dtypes
# Out:
# Item                   object
# Item_Code               int64
# Quantity              float64
# Unit_Price            float64
# Total_Sales_Amount    float64
# date                   object
# dtype: object

# %%
df.shape
# Out:
# (15585, 6)

# %%
data = df.sample(frac=0.95, random_state=786).reset_index(drop=True)
data_unseen = df.drop(data.index).reset_index(drop=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (14806, 6)
# Unseen Data For Predictions: (779, 6)

# %%
# Create our features
X = pd.get_dummies(data=df, columns=['Total_Sales_Amount', 'date'])
# Create our target
y = df["Total_Sales_Amount"]

# %%
X.describe()
# Out:
#           Item_Code      Quantity    Unit_Price  Total_Sales_Amount_0.0  \
# count  15585.000000  15585.000000  15585.000000            15585.000000
# mean    3362.503818     12.521976      5.273758                0.039525
# std      173.109261     20.487179      5.395541                0.194847
# min     3113.000000      1.000000      0.000000                0.000000
# 25%     3210.000000      2.000000      3.394737                0.000000
# 50%     3353.000000      5.000000      4.267241                0.000000
# 75%     3492.000000     14.000000      7.000000                0.000000
# max     3717.000000    293.000000    206.000000                1.000000
#
#        Total_Sales_Amount_0.75  Total_Sales_Amount_1.5  \
# count             15585.000000            15585.000000
# mean                  0.001219                0.000834
# std                   0.034896                0.028870
# min                   0.000000                0.000000
# 25%                   0.000000                0.000000
# 50%                   0.000000                0.000000
# 75%                   0.000000                0.000000
# max                   1.000000                1.000000
#
#        Total_Sales_Amount_2.0  Total_Sales_Amount_2.25  \
# count            15585.000000             15585.000000
# mean                 0.000962                 0.000513
# std                  0.031010                 0.022651
# min                  0.000000                 0.000000
# 25%                  0.000000                 0.000000
# 50%                  0.000000                 0.000000
# 75%                  0.000000                 0.000000
# max                  1.000000                 1.000000
#
#        Total_Sales_Amount_3.0  Total_Sales_Amount_3.25  ...  date_2021-07-16  \
# count            15585.000000             15585.000000  ...     15585.000000
# mean                 0.019249                 0.002695  ...         0.008341
# std                  0.137404                 0.051844  ...         0.090952
# min                  0.000000                 0.000000  ...         0.000000
# 25%                  0.000000                 0.000000  ...         0.000000
# 50%                  0.000000                 0.000000  ...         0.000000
# 75%                  0.000000                 0.000000  ...         0.000000
# max                  1.000000                 1.000000  ...         1.000000
#
#        date_2021-07-23  date_2021-07-30  date_2021-08-06  date_2021-08-13  \
# count     15585.000000     15585.000000     15585.000000     15585.000000
# mean          0.008791         0.008406         0.007956         0.007507
# std           0.093348         0.091298         0.088846         0.086321
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         0.000000         0.000000
# max           1.000000         1.000000         1.000000         1.000000
#
#        date_2021-08-20  date_2021-08-27  date_2021-09-03  date_2021-09-10  \
# count     15585.000000     15585.000000     15585.000000     15585.000000
# mean          0.008213         0.008406         0.007892         0.008277
# std           0.090256         0.091298         0.088490         0.090605
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         0.000000         0.000000
# max           1.000000         1.000000         1.000000         1.000000
#
#        date_2021-09-17
# count     15585.000000
# mean          0.008213
# std           0.090256
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
#
# [8 rows x 910 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1)
Counter(y_train)
# Out:
# Counter({26.0: 27,
#          94.5: 6,
#          135.0: 36,
#          32.0: 172,
#          5.0: 328,
#          112.5: 8,
#          484.0: 3,
#          15.0: 279,
#          6.0: 355,
#          8.0: 646,
#          14.0: 176,
#          0.0: 476,
#          4.5: 110,
#          72.0: 71,
#          42.0: 83,
#          99.0: 20,
#          30.0: 182,
#          16.0: 415,
#          4.0: 491,
#          130.0: 12,
#          44.0: 64,
#          24.0: 321,
#          3.0: 234,
#          676.0: 1,
#          123.0: 11,
#          10.5: 15,
#          12.0: 414,
#          152.0: 11,
#          115.0: 7,
#          84.0: 51,
#          34.0: 10,
#          68.25: 5,
#          312.0: 3,
#          48.0: 140,
#          50.0: 24,
#          33.0: 58,
#          9.0: 241,
#          131.5: 2,
#          264.0: 8,
#          522.5: 1,
#          209.0: 10,
#          70.0: 23,
#          31.5: 41,
#          7.0: 268,
#          18.0: 185,
#          165.0: 39,
#          37.5: 5,
#          68.0: 40,
#          114.0: 20,
#          27.0: 85,
#          40.0: 151,
#          90.0: 59,
#          34.5: 11,
#          47.5: 2,
#          45.5: 18,
#          49.5: 22,
#          21.0: 151,
#          28.0: 165,
#          246.0: 1,
#          184.0: 7,
#          108.0: 23,
#          286.0: 6,
#          159.0: 11,
#          3.25: 35,
#          139.0: 2,
#          10.0: 235,
#          176.0: 25,
#          240.0: 17,
#          124.0: 12,
#          36.0: 155,
#          20.0: 237,
#          67.5: 16,
#          35.0: 86,
#          170.0: 5,
#          506.0: 2,
#          30.5: 2,
#          116.0: 20,
#          76.0: 30,
#          6.5: 47,
#          39.0: 33,
#          16.5: 16,
#          22.5: 44,
#          56.0: 106,
#          187.0: 4,
#          178.75: 1,
#          88.0: 59,
#          638.0: 1,
#          93.0: 16,
#          304.25: 1,
#          120.0: 64,
#          13.0: 41,
#          155.0: 7,
#          255.0: 9,
#          173.0: 1,
#          49.0: 30,
#          253.0: 5,
#          13.5: 69,
#          11.0: 62,
#          188.0: 8,
#          136.0: 24,
#          22.75: 22,
#          57.0: 23,
#          462.0: 7,
#          150.0: 35,
#          100.0: 31,
#          64.5: 8,
#          160.0: 21,
#          59.5: 2,
#          24.5: 11,
#          45.0: 104,
#          60.0: 112,
#          77.0: 24,
#          126.0: 11,
#          156.0: 19,
#          80.0: 46,
#          29.0: 7,
#          540.0: 5,
#          654.0: 1,
#          228.0: 7,
#          244.5: 2,
#          324.0: 6,
#          396.0: 1,
#          212.0: 8,
#          143.0: 13,
#          25.0: 63,
#          75.0: 55,
#          166.5: 2,
#          144.0: 20,
#          192.0: 17,
#          137.0: 2,
#          0.75: 15,
#          141.0: 12,
#          70.5: 6,
#          53.5: 3,
#          129.0: 9,
#          207.0: 3,
#          25.5: 12,
#          140.0: 24,
#          104.0: 36,
#          473.0: 3,
#          216.0: 8,
#          308.0: 5,
#          244.0: 5,
#          117.0: 21,
#          11.5: 2,
#          19.5: 30,
#          55.0: 33,
#          17.5: 20,
#          3.5: 69,
#          261.0: 5,
#          63.0: 59,
#          96.0: 38,
#          336.0: 2,
#          109.5: 3,
#          87.0: 18,
#          92.5: 3,
#          125.0: 7,
#          284.0: 5,
#          74.0: 3,
#          525.0: 2,
#          252.0: 8,
#          163.5: 5,
#          69.0: 21,
#          40.5: 18,
#          119.0: 4,
#          61.5: 12,
#          152.5: 1,
#          270.5: 1,
#          390.0: 5,
#          295.0: 1,
#          260.0: 7,
#          48.5: 3,
#          451.0: 2,
#          106.0: 6,
#          204.0: 8,
#          65.0: 21,
#          211.5: 3,
#          5.5: 15,
#          2.25: 6,
#          191.75: 2,
#          102.0: 16,
#          64.0: 79,
#          232.0: 5,
#          168.0: 15,
#          52.0: 45,
#          199.5: 1,
#          46.5: 8,
#          53.0: 10,
#          29.02: 1,
#          28.5: 14,
#          54.0: 50,
#          121.0: 9,
#          66.0: 41,
#          171.0: 5,
#          128.0: 20,
#          22.0: 45,
#          304.0: 3,
#          23.0: 7,
#          36.5: 1,
#          81.0: 24,
#          103.5: 6,
#          58.5: 22,
#          16.25: 14,
#          250.0: 3,
#          154.0: 9,
#          96.5: 2,
#          600.0: 1,
#          61.0: 9,
#          405.0: 2,
#          172.0: 5,
#          344.0: 2,
#          340.5: 1,
#          132.0: 32,
#          42.25: 5,
#          124.5: 7,
#          198.0: 10,
#          208.0: 5,
#          38.0: 7,
#          73.5: 8,
#          299.0: 1,
#          245.0: 3,
#          105.0: 37,
#          110.0: 18,
#          195.0: 17,
#          429.0: 4,
#          106.5: 6,
#          951.75: 1,
#          160.75: 1,
#          112.0: 28,
#          9.75: 35,
#          104.5: 4,
#          94.0: 2,
#          571.0: 1,
#          105.5: 2,
#          360.0: 7,
#          256.0: 10,
#          55.5: 14,
#          709.0: 1,
#          51.0: 24,
#          420.0: 6,
#          15.25: 1,
#          151.0: 3,
#          438.0: 1,
#          555.0: 5,
#          260.5: 1,
#          115.5: 7,
#          196.0: 6,
#          33.5: 3,
#          54.5: 6,
#          189.0: 7,
#          113.5: 1,
#          147.0: 10,
#          288.0: 2,
#          92.0: 16,
#          52.5: 9,
#          225.0: 12,
#          118.5: 3,
#          210.0: 13,
#          265.0: 1,
#          250.25: 1,
#          211.25: 2,
#          9.5: 6,
#          21.5: 2,
#          79.0: 4,
#          182.0: 4,
#          249.0: 3,
#          704.0: 2,
#          35.75: 9,
#          247.5: 5,
#          187.75: 1,
#          148.0: 9,
#          59.0: 3,
#          450.0: 3,
#          230.0: 2,
#          134.5: 3,
#          120.5: 1,
#          149.5: 3,
#          671.0: 1,
#          550.0: 2,
#          29.25: 8,
#          31.0: 4,
#          101.5: 3,
#          200.0: 8,
#          169.5: 1,
#          91.5: 9,
#          166.0: 1,
#          97.5: 9,
#          220.0: 9,
#          148.5: 3,
#          204.75: 3,
#          138.0: 9,
#          332.0: 3,
#          270.0: 8,
#          231.0: 9,
#          248.0: 5,
#          352.0: 3,
#          285.0: 4,
#          35.5: 2,
#          185.0: 4,
#          187.5: 6,
#          113.0: 3,
#          186.0: 3,
#          1004.5: 1,
#          179.0: 3,
#          206.0: 2,
#          121.5: 5,
#          156.5: 1,
#          2.0: 10,
#          100.5: 4,
#          61.75: 7,
#          527.75: 1,
#          276.0: 1,
#          39.5: 3,
#          344.75: 1,
#          86.5: 2,
#          130.5: 7,
#          19.0: 11,
#          367.25: 2,
#          181.5: 2,
#          37.0: 11,
#          180.0: 26,
#          265.5: 2,
#          48.75: 11,
#          73.0: 5,
#          38.5: 7,
#          41.0: 6,
#          220.5: 5,
#          95.0: 8,
#          306.0: 2,
#          17.0: 7,
#          234.0: 3,
#          384.0: 2,
#          297.0: 4,
#          468.0: 1,
#          407.0: 3,
#          331.5: 2,
#          78.0: 19,
#          8.5: 2,
#          957.0: 2,
#          375.0: 2,
#          693.0: 2,
#          71.5: 2,
#          211.0: 2,
#          99.5: 1,
#          14.25: 1,
#          133.0: 4,
#          175.5: 3,
#          177.0: 6,
#          781.75: 1,
#          32.5: 9,
#          283.5: 1,
#          435.0: 3,
#          283.0: 1,
#          226.5: 2,
#          315.0: 6,
#          1001.0: 2,
#          416.0: 1,
#          477.5: 1,
#          404.5: 1,
#          160.5: 4,
#          201.0: 5,
#          131.0: 4,
#          184.5: 2,
#          175.0: 2,
#          403.0: 1,
#          1.5: 9,
#          185.25: 3,
#          167.5: 1,
#          224.0: 7,
#          85.0: 12,
#          154.5: 3,
#          832.75: 1,
#          528.0: 3,
#          190.0: 5,
#          43.5: 12,
#          361.5: 1,
#          302.0: 1,
#          257.0: 2,
#          90.5: 3,
#          279.0: 1,
#          328.0: 3,
#          46.0: 5,
#          605.5: 1,
#          42.5: 5,
#          133.25: 2,
#          36.25: 1,
#          95.5: 1,
#          98.0: 5,
#          277.5: 1,
#          273.0: 2,
#          585.0: 1,
#          205.0: 1,
#          5.25: 1,
#          914.5: 1,
#          272.0: 4,
#          296.0: 3,
#          129.5: 1,
#          608.0: 1,
#          76.5: 7,
#          183.0: 5,
#          641.0: 1,
#          87.75: 2,
#          20.5: 6,
#          111.0: 7,
#          88.5: 3,
#          770.0: 1,
#          44.5: 1,
#          165.75: 3,
#          161.0: 1,
#          98.5: 2,
#          276.25: 1,
#          319.0: 7,
#          138.5: 1,
#          162.0: 8,
#          300.0: 2,
#          109.0: 1,
#          126.75: 2,
#          587.0: 1,
#          26.5: 1,
#          171.5: 1,
#          1021.0: 1,
#          58.0: 6,
#          100.75: 2,
#          334.75: 1,
#          412.0: 3,
#          356.0: 1,
#          315.25: 1,
#          7.5: 6,
#          119.5: 1,
#          83.5: 3,
#          55.25: 5,
#          164.0: 11,
#          660.0: 1,
#          157.0: 1,
#          103.0: 4,
#          107.25: 2,
#          85.5: 5,
#          292.0: 3,
#          330.0: 8,
#          86.0: 5,
#          133.5: 5,
#          483.5: 1,
#          127.0: 3,
#          80.5: 3,
#          282.0: 2,
#          212.5: 1,
#          178.5: 2,
#          173.5: 1,
#          79.5: 2,
#          67.0: 5,
#          248.5: 1,
#          281.0: 1,
#          101.0: 3,
#          363.0: 2,
#          117.5: 2,
#          71.0: 2,
#          74.75: 1,
#          268.0: 2,
#          174.0: 3,
#          476.0: 2,
#          432.0: 2,
#          89.0: 7,
#          611.75: 1,
#          15.5: 2,
#          153.0: 6,
#          1053.5: 1,
#          151.5: 2,
#          60.5: 3,
#          27.5: 6,
#          191.0: 1,
#          495.0: 2,
#          139.5: 2,
#          91.0: 11,
#          268.5: 1,
#          527.0: 1,
#          97.0: 1,
#          57.5: 3,
#          628.5: 1,
#          592.75: 1,
#          80.75: 1,
#          307.5: 1,
#          480.0: 3,
#          120.25: 5,
#          118.0: 1,
#          174.5: 2,
#          84.5: 3,
#          145.0: 3,
#          345.0: 5,
#          3090.0: 1,
#          157.5: 4,
#          372.0: 3,
#          153.5: 1,
#          142.0: 3,
#          110.5: 5,
#          520.0: 1,
#          385.0: 2,
#          108.5: 3,
#          400.0: 2,
#          381.0: 2,
#          799.0: 1,
#          583.0: 2,
#          418.0: 1,
#          222.5: 2,
#          250.5: 1,
#          77.5: 1,
#          66.5: 1,
#          238.5: 2,
#          75.75: 1,
#          341.0: 3,
#          208.5: 2,
#          194.0: 3,
#          68.5: 1,
#          651.5: 1,
#          366.0: 1,
#          275.0: 2,
#          339.0: 1,
#          464.75: 1,
#          682.0: 2,
#          564.0: 1,
#          205.5: 2,
#          219.0: 2,
#          256.5: 2,
#          304.5: 2,
#          978.0: 1,
#          309.0: 1,
#          720.0: 1,
#          159.5: 2,
#          165.5: 1,
#          449.25: 1,
#          50.5: 1,
#          122.0: 3,
#          75.5: 1,
#          82.0: 4,
#          291.0: 1,
#          798.25: 1,
#          440.0: 4,
#          630.0: 2,
#          599.0: 1,
#          224.25: 2,
#          223.5: 1,
#          94.25: 2,
#          370.0: 1,
#          684.0: 1,
#          78.5: 3,
#          338.5: 1,
#          213.0: 6,
#          65.5: 4,
#          215.0: 4,
#          465.0: 1,
#          196.5: 1,
#          448.0: 1,
#          220.75: 1,
#          172.5: 1,
#          616.0: 1,
#          1013.0: 1,
#          172.25: 1,
#          107.5: 1,
#          82.5: 4,
#          279.5: 1,
#          373.0: 1,
#          43.0: 3,
#          149.0: 1,
#          81.25: 2,
#          397.5: 1,
#          341.25: 1,
#          230.25: 1,
#          615.0: 1,
#          628.0: 1,
#          63.5: 2,
#          256.75: 1,
#          443.25: 1,
#          505.25: 1,
#          338.0: 1,
#          690.0: 1,
#          23.25: 1,
#          51.5: 3,
#          301.5: 1,
#          381.5: 1,
#          210.75: 1,
#          733.75: 1,
#          56.5: 2,
#          289.5: 1,
#          346.0: 1,
#          627.0: 1,
#          1167.25: 1,
#          190.5: 2,
#          601.25: 1,
#          658.75: 1,
#          237.0: 1,
#          262.5: 2,
#          202.5: 5,
#          5974.0: 1,
#          128.75: 1,
#          510.25: 1,
#          199.0: 1,
#          485.75: 1,
#          286.5: 1,
#          242.0: 3,
#          746.0: 1,
#          258.0: 2,
#          1089.0: 2,
#          292.5: 1,
#          566.5: 1,
#          254.25: 1,
#          146.0: 2,
#          134.0: 1,
#          313.5: 2,
#          1031.5: 1,
#          214.5: 1,
#          164.5: 1,
#          349.0: 1,
#          869.0: 1,
#          409.75: 1,
#          428.0: 2,
#          132.5: 2,
#          825.0011: 1,
#          455.0: 1,
#          576.0: 1,
#          1083.75: 1,
#          30.75: 1,
#          218.0: 1,
#          539.0: 3,
#          240.5: 2,
#          570.0: 1,
#          327.0: 1,
#          376.0: 2,
#          479.0: 1,
#          737.0: 1,
#          348.0: 2,
#          253.5: 2,
#          41.5: 2,
#          781.0: 1,
#          158.0: 1,
#          123.5: 1,
#          691.5: 1,
#          29.5: 2,
#          193.0: 1,
#          328.5: 1,
#          193.5: 2,
#          735.25: 1,
#          342.0: 1,
#          580.75: 1,
#          136.5: 2,
#          510.0: 1,
#          239.0: 1,
#          586.0: 1,
#          618.0: 2,
#          322.5: 1,
#          243.75: 1,
#          364.0: 3,
#          980.0: 1,
#          194.5: 1,
#          123.85: 1,
#          474.0: 1,
#          197.0: 2,
#          47.0: 6,
#          719.0: 1,
#          476.5: 1,
#          388.0: 2,
#          293.5: 1,
#          607.25: 1,
#          377.0: 1,
#          565.5: 1,
#          145.5: 1,
#          243.0: 2,
#          222.0: 2,
#          365.0: 1,
#          486.0: 1,
#          370.5: 1,
#          325.0: 1,
#          146.5: 2,
#          235.5: 1,
#          561.0: 1,
#          337.5: 1,
#          152.75: 1,
#          560.5: 1,
#          436.0: 1,
#          8.25: 1,
#          516.0: 2,
#          111.5: 1,
#          162.5: 1,
#          225.25: 1,
#          177.5: 1,
#          62.0: 1,
#          501.5: 1,
#          214.0: 1,
#          161.5: 1,
#          349.5: 1,
#          102.5: 1,
#          406.25: 1,
#          107.0: 1,
#          989.5: 1,
#          217.75: 1,
#          481.5: 1,
#          147.5: 1,
#          520.25: 1,
#          197.5: 1,
#          18.5: 1,
#          374.0: 1,
#          188.5: 1,
#          87.5: 1,
#          340.0: 1,
#          12.5: 1,
#          794.25: 1,
#          1000.25: 1,
#          867.0: 1,
#          517.0: 1,
#          886.5: 1,
#          280.5: 1,
#          14.5: 1,
#          444.0: 1})

# %% [markdown]
# # Balanced Random Forest Classifier

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
random_forest = BalancedRandomForestClassifier(n_estimators = 100)
random_forest = random_forest.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f2cc4ebb8d6e> in <module>
#       1 from imblearn.ensemble import BalancedRandomForestClassifier
#       2 random_forest = BalancedRandomForestClassifier(n_estimators = 100)
# ----> 3 random_forest = random_forest.fit(X_train, y_train)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\imblearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     423             )
#     424         X, y = self._validate_data(X, y, multi_output=True,
# --> 425                                    accept_sparse="csc", dtype=DTYPE)
#     426         if sample_weight is not None:
#     427             sample_weight = _check_sample_weight(sample_weight, X)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'BTL Miller Lite'
